# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load The Historical Dataset

# %%
# Convert csv into dataframe
df = pd.read_csv('Converted_Energy_Consumption.csv')
print(df.to_string())
# Out:
#       Id  Year  Fuel_Type_Id  Consumption         Units
# 0      1  1950             1      5974.61  Trillion BTU
# 1      2  1955             1      9006.98  Trillion BTU
# 2      3  1960             1     12397.81  Trillion BTU
# 3      4  1965             1     15830.08  Trillion BTU
# 4      5  1970             1     21900.00  Trillion BTU
# 5      6  1975             1     20241.37  Trillion BTU
# 6      7  1980             1     20592.57  Trillion BTU
# 7      8  1985             1     17903.12  Trillion BTU
# 8      9  1990             1     19864.26  Trillion BTU
# 9     10  1995             1     23006.45  Trillion BTU
# 10    11  2000             1     24172.99  Trillion BTU
# 11    12  2005             1     22806.50  Trillion BTU
# 12    13  2010             1     24954.13  Trillion BTU
# 13    14  2011             1     25358.17  Trillion BTU
# 14    15  2012             1     26457.37  Trillion BTU
# 15    16  2013             1     27096.58  Trillion BTU
# 16    17  2014             1     27550.35  Trillion BTU
# 17    18  2015             1     28224.78  Trillion BTU
# 18    19  2016             1     28431.98  Trillion BTU
# 19    20  2017             1     28123.26  Trillion BTU
# 20    21  2018             1     31234.36  Trillion BTU
# 21    22  2019             1     32264.15  Trillion BTU
# 22    23  2020             1     31674.66  Trillion BTU
# 23    24  2021             1     31749.26  Trillion BTU
# 24    25  2022             1     33423.43  Trillion BTU
# 25    26  2023             1     33676.22  Trillion BTU
# 26    27  1950             2     13398.15  Trillion BTU
# 27    28  1955             2     17541.25  Trillion BTU
# 28    29  1960             2     20325.44  Trillion BTU
# 29    30  1965             2     23883.49  Trillion BTU
# 30    31  1970             2     30491.28  Trillion BTU
# 31    32  1975             2     33862.60  Trillion BTU
# 32    33  1980             2     35385.40  Trillion BTU
# 33    34  1985             2     32626.10  Trillion BTU
# 34    35  1990             2     35244.32  Trillion BTU
# 35    36  1995             2     36773.35  Trillion BTU
# 36    37  2000             2     40872.88  Trillion BTU
# 37    38  2005             2     43157.08  Trillion BTU
# 38    39  2010             2     39787.83  Trillion BTU
# 39    40  2011             2     39202.78  Trillion BTU
# 40    41  2012             2     38231.83  Trillion BTU
# 41    42  2013             2     39350.08  Trillion BTU
# 42    43  2014             2     39626.01  Trillion BTU
# 43    44  2015             2     40522.26  Trillion BTU
# 44    45  2016             2     40854.20  Trillion BTU
# 45    46  2017             2     41393.62  Trillion BTU
# 46    47  2018             2     42555.43  Trillion BTU
# 47    48  2019             2     42619.74  Trillion BTU
# 48    49  2020             2     37729.77  Trillion BTU
# 49    50  2021             2     41264.99  Trillion BTU
# 50    51  2022             2     41513.95  Trillion BTU
# 51    52  2023             2     42003.57  Trillion BTU
# 52    53  1950             3      9299.00  Trillion BTU
# 53    54  1955             3      8412.77  Trillion BTU
# 54    55  1960             3      7491.88  Trillion BTU
# 55    56  1965             3      8882.38  Trillion BTU
# 181  182  2020             8      2136.00  Trillion BTU
# 182  183  2021             8      2331.00  Trillion BTU
# 183  184  2022             8      2433.00  Trillion BTU
# 184  185  2023             8      2662.00  Trillion BTU
# 185  186  1991             9       598.58  Trillion BTU
# 186  187  1992             9       743.90  Trillion BTU
# 187  188  1993             9       780.23  Trillion BTU
# 188  189  1994             9       698.92  Trillion BTU
# 189  190  1995             9       884.03  Trillion BTU
# 190  191  1996             9       799.26  Trillion BTU
# 191  192  1997             9       833.86  Trillion BTU
# 192  193  1998             9       660.86  Trillion BTU
# 193  194  1999             9      1006.86  Trillion BTU
# 194  195  2000             9       890.95  Trillion BTU
# 195  196  2001             9       911.71  Trillion BTU
# 196  197  2002             9       989.56  Trillion BTU
# 197  198  2003             9      1077.79  Trillion BTU
# 198  199  2004             9       866.73  Trillion BTU
# 199  200  2005             9      1008.59  Trillion BTU
# 200  201  2006             9       894.41  Trillion BTU
# 201  202  2007             9       787.15  Trillion BTU
# 202  203  2008             9       887.49  Trillion BTU
# 203  204  2009             9       854.62  Trillion BTU
# 204  205  2010             9       766.39  Trillion BTU
# 205  206  2011             9       880.57  Trillion BTU
# 206  207  2012             9       856.35  Trillion BTU
# 207  208  2013             9       736.98  Trillion BTU
# 208  209  2014             9       873.65  Trillion BTU
# 209  210  2015             9       820.02  Trillion BTU
# 210  211  2016             9       721.41  Trillion BTU
# 211  212  2017             9       787.15  Trillion BTU
# 212  213  2018             9       871.92  Trillion BTU
# 213  214  2019             9       747.36  Trillion BTU
# 214  215  2020             9       840.78  Trillion BTU
# 215  216  2021             9       768.12  Trillion BTU
# 216  217  2022             9       768.12  Trillion BTU
# 217  218  2023             9       759.47  Trillion BTU

# %% [raw]
# Train the SVR Model with a Radial Basis Function (RBF) Kernel

# %%
# Preprocess features
X = df[['Year', 'Fuel_Type_Id']]
y = df[['Consumption']]

# Encode categorial feature (Fuel_Type_id) & scale the numerical feature (Year)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['Year']),
        ('cat', OneHotEncoder(), ['Fuel_Type_Id'])
    ]
)

# Define the models pipeline
model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', SVR(kernel='rbf'))
    ]
)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train model
model.fit(X_train, y_train)

# Make Predictions
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print metrics
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'R-squared (R2): {r2:.2f}')

# Evaluate the model
plt.scatter(X_test['Year'], y_test, color='darkorange', label='True values')
plt.scatter(X_test['Year'], y_pred, color='cornflowerblue', label='Predictions')
plt.xlabel('Year')
plt.ylabel('Consumption')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 17
#       6 preprocessor = ColumnTransformer(
#       7     transformers=[
#       8         ('num', StandardScaler(), ['Year']),
#       9         ('cat', OneHotEncoder(), ['Fuel_Type_Id'])
#      10     ]
#      11 )
#      13 # Define the models pipeline
#      14 model = Pipeline(
#      15     steps=[
#      16         ('preprocessor', preprocessor),
# ---> 17         ('regressor', SVR(kernal='rbf'))
#      18     ]
#      19 )
#      21 # Split data
#      22 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#
# TypeError: __init__() got an unexpected keyword argument 'kernal'
